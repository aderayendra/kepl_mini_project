# %% [markdown]
# ![image.png](attachment:6678963c-2903-47b0-9241-08aec10d37c7.png)

# %% [markdown]
# 9![image.png](attachment:802c76a8-6370-474f-b741-7d00dc01a471.png)

# %% [markdown]
# ![image.png](attachment:1bc75cbd-d841-4836-a8a2-73b78a70eb88.png)

# %% [markdown]
#  ![image.png](attachment:c934eb7b-93f9-466f-aa03-b0263e51550e.png)
